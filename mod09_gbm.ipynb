# %%
# packages
import os
import joblib
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import GradientBoostingRegressor as GBR
from sklearn.model_selection import GridSearchCV

# set seed
seed = 5151

# %% [markdown]
# ### You'll need the California housing data (CAhousing.csv) to complete this exercise. Your goal is to predict the median house value.

# %%
CAhousing = pd.read_csv('data/CAhousing.csv')
CAhousing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -120.45     34.66                 7.0       3329.0           504.0
# 1    -114.64     34.83                10.0       2502.0           573.0
# 2    -117.24     32.74                43.0       2216.0           375.0
# 3    -122.43     37.76                52.0       3771.0          1017.0
# 4    -118.02     34.13                34.0       1966.0           319.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0      1462.0       452.0         4.7875            198300.0      NEAR OCEAN
# 1      1152.0       481.0         1.7062             86800.0          INLAND
# 2       918.0       388.0         5.5289            297700.0      NEAR OCEAN
# 3      1575.0       921.0         3.5655            427300.0        NEAR BAY
# 4       980.0       297.0         7.7307            429000.0          INLAND

# %%
CAhousing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
CAhousing.shape
# Out:
# (15480, 10)

# %% [markdown]
# ### There is a single categorical variable in this dataset that we will convert to a series of binary variables.

# %%
CAhousing['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6857
# INLAND        4933
# NEAR OCEAN    1974
# NEAR BAY      1712
# ISLAND           4
# Name: count, dtype: int64

# %%
# create binary variables for levels which have enough records, using '<1H OCEAN' as base.
CAhousing['ocean_prox_inland'] = (CAhousing.ocean_proximity == 'INLAND').astype(int)
CAhousing['ocean_prox_nearocean'] = (CAhousing.ocean_proximity == 'NEAR OCEAN').astype(int)
CAhousing['ocean_prox_nearbay'] = (CAhousing.ocean_proximity == 'NEAR BAY').astype(int)

# check for intended outcome
print(CAhousing['ocean_prox_inland'].value_counts())
print(CAhousing['ocean_prox_nearocean'].value_counts())
print(CAhousing['ocean_prox_nearbay'].value_counts())
# Out:
# ocean_prox_inland
# 0    10547
# 1     4933
# Name: count, dtype: int64
# ocean_prox_nearocean
# 0    13506
# 1     1974
# Name: count, dtype: int64
# ocean_prox_nearbay
# 0    13768
# 1     1712
# Name: count, dtype: int64

# %%
indep_vars = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 
              'total_bedrooms', 'population', 'households', 'median_income', 
              'ocean_prox_inland', 'ocean_prox_nearocean', 'ocean_prox_nearbay']

X = CAhousing[indep_vars]
y = CAhousing['median_house_value']

# %%
X_train, X_test, y_train, y_test, Train, Test = train_test_split(X, y, CAhousing, 
                                                                 random_state = seed, 
                                                                 test_size = 0.33, 
                                                                 shuffle = True)

# %%
X_train.corr().style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_15868_row0_col0, #T_15868_row1_col1, #T_15868_row2_col2, #T_15868_row3_col3, #T_15868_row4_col4, #T_15868_row5_col5, #T_15868_row6_col6, #T_15868_row7_col7, #T_15868_row8_col8, #T_15868_row9_col9, #T_15868_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_15868_row0_col1, #T_15868_row1_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_15868_row0_col2, #T_15868_row2_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_15868_row0_col3, #T_15868_row3_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_15868_row0_col4, #T_15868_row4_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_15868_row0_col5, #T_15868_row5_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_15868_row0_col6, #T_15868_row6_col0, #T_15868_row7_col10, #T_15868_row10_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_15868_row0_col7, #T_15868_row3_col9, #T_15868_row7_col0, #T_15868_row9_col3 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_15868_row0_col8, #T_15868_row1_col4, #T_15868_row4_col1, #T_15868_row5_col10, #T_15868_row8_col0, #T_15868_row10_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_15868_row0_col9, #T_15868_row9_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_15868_row0_col10, #T_15868_row10_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_15868_row1_col2, #T_15868_row2_col1, #T_15868_row2_col9, #T_15868_row3_col8, #T_15868_row8_col3, #T_15868_row9_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_15868_row1_col3, #T_15868_row3_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_15868_row1_col5, #T_15868_row5_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_15868_row1_col6, #T_15868_row6_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_15868_row1_col7, #T_15868_row7_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_15868_row1_col8, #T_15868_row8_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_15868_row1_col9, #T_15868_row9_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_15868_row1_col10, #T_15868_row10_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_15868_row2_col3, #T_15868_row3_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_15868_row2_col4, #T_15868_row4_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_15868_row2_col5, #T_15868_row5_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_15868_row2_col6, #T_15868_row6_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_15868_row2_col7, #T_15868_row7_col2, #T_15868_row9_col10, #T_15868_row10_col9 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_15868_row2_col8, #T_15868_row7_col8, #T_15868_row8_col2, #T_15868_row8_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_15868_row2_col10, #T_15868_row10_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_15868_row3_col4, #T_15868_row4_col3 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_15868_row3_col5, #T_15868_row5_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_15868_row3_col6, #T_15868_row6_col3 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_15868_row3_col7, #T_15868_row7_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_15868_row3_col10, #T_15868_row5_col8, #T_15868_row8_col5, #T_15868_row10_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_15868_row4_col5, #T_15868_row5_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_15868_row4_col6, #T_15868_row6_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_15868_row4_col7, #T_15868_row4_col8, #T_15868_row5_col9, #T_15868_row7_col4, #T_15868_row8_col4, #T_15868_row9_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_15868_row4_col9, #T_15868_row5_col7, #T_15868_row6_col9, #T_15868_row7_col5, #T_15868_row9_col4, #T_15868_row9_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_15868_row4_col10, #T_15868_row6_col10, #T_15868_row10_col4, #T_15868_row10_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_15868_row5_col6, #T_15868_row6_col5 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_15868_row6_col7, #T_15868_row7_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_15868_row6_col8, #T_15868_row8_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_15868_row7_col9, #T_15868_row9_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_15868_row8_col9, #T_15868_row9_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_15868_row8_col10, #T_15868_row10_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# </style>
# <table id="T_15868">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15868_level0_col0" class="col_heading level0 col0" >longitude</th>
#       <th id="T_15868_level0_col1" class="col_heading level0 col1" >latitude</th>
#       <th id="T_15868_level0_col2" class="col_heading level0 col2" >housing_median_age</th>
#       <th id="T_15868_level0_col3" class="col_heading level0 col3" >total_rooms</th>
#       <th id="T_15868_level0_col4" class="col_heading level0 col4" >total_bedrooms</th>
#       <th id="T_15868_level0_col5" class="col_heading level0 col5" >population</th>
#       <th id="T_15868_level0_col6" class="col_heading level0 col6" >households</th>
#       <th id="T_15868_level0_col7" class="col_heading level0 col7" >median_income</th>
#       <th id="T_15868_level0_col8" class="col_heading level0 col8" >ocean_prox_inland</th>
#       <th id="T_15868_level0_col9" class="col_heading level0 col9" >ocean_prox_nearocean</th>
#       <th id="T_15868_level0_col10" class="col_heading level0 col10" >ocean_prox_nearbay</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15868_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_15868_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_15868_row0_col1" class="data row0 col1" >-0.924779</td>
#       <td id="T_15868_row0_col2" class="data row0 col2" >-0.118552</td>
#       <td id="T_15868_row0_col3" class="data row0 col3" >0.044445</td>
#       <td id="T_15868_row0_col4" class="data row0 col4" >0.067878</td>
#       <td id="T_15868_row0_col5" class="data row0 col5" >0.095517</td>
#       <td id="T_15868_row0_col6" class="data row0 col6" >0.056249</td>
#       <td id="T_15868_row0_col7" class="data row0 col7" >-0.001915</td>
#       <td id="T_15868_row0_col8" class="data row0 col8" >-0.068406</td>
#       <td id="T_15868_row0_col9" class="data row0 col9" >0.047632</td>
#       <td id="T_15868_row0_col10" class="data row0 col10" >-0.471177</td>
#     </tr>
#     <tr>
#       <th id="T_15868_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_15868_row1_col0" class="data row1 col0" >-0.924779</td>
#       <td id="T_15868_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_15868_row1_col2" class="data row1 col2" >0.017276</td>
#       <td id="T_15868_row1_col3" class="data row1 col3" >-0.034301</td>
#       <td id="T_15868_row1_col4" class="data row1 col4" >-0.064393</td>
#       <td id="T_15868_row1_col5" class="data row1 col5" >-0.104774</td>
#       <td id="T_15868_row1_col6" class="data row1 col6" >-0.070660</td>
#       <td id="T_15868_row1_col7" class="data row1 col7" >-0.091395</td>
#       <td id="T_15868_row1_col8" class="data row1 col8" >0.362431</td>
#       <td id="T_15868_row1_col9" class="data row1 col9" >-0.162865</td>
#       <td id="T_15868_row1_col10" class="data row1 col10" >0.352288</td>
#     </tr>
#     <tr>
#       <th id="T_15868_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_15868_row2_col0" class="data row2 col0" >-0.118552</td>
#       <td id="T_15868_row2_col1" class="data row2 col1" >0.017276</td>
#       <td id="T_15868_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_15868_row2_col3" class="data row2 col3" >-0.356225</td>
#       <td id="T_15868_row2_col4" class="data row2 col4" >-0.312179</td>
#       <td id="T_15868_row2_col5" class="data row2 col5" >-0.296755</td>
#       <td id="T_15868_row2_col6" c

# %%
Train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  10371.000000  10371.000000        10371.000000  10371.000000
# mean    -119.576317     35.648347           28.707646   2631.445569
# std        1.997211      2.140070           12.631120   2173.616930
# min     -124.260000     32.560000            1.000000      8.000000
# 25%     -121.770000     33.940000           18.000000   1454.000000
# 50%     -118.510000     34.260000           29.000000   2126.000000
# 75%     -118.020000     37.730000           37.000000   3127.000000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    10257.000000  10371.000000  10371.000000   10371.000000
# mean       537.541484   1426.518851    500.422524       3.868065
# std        425.582759   1137.463225    388.555637       1.885826
# min          1.000000      5.000000      1.000000       0.499900
# 25%        296.000000    791.000000    282.000000       2.556800
# 50%        435.000000   1163.000000    410.000000       3.534500
# 75%        640.000000   1719.000000    601.000000       4.747400
# max       6445.000000  28566.000000   6082.000000      15.000100
#
#        median_house_value  ocean_prox_inland  ocean_prox_nearocean  \
# count        10371.000000       10371.000000          10371.000000
# mean        206399.612284           0.323787              0.124771
# std         115215.425942           0.467943              0.330475
# min          14999.000000           0.000000              0.000000
# 25%         118750.000000           0.000000              0.000000
# 50%         179800.000000           0.000000              0.000000
# 75%         264000.000000           1.000000              0.000000
# max         500001.000000           1.000000              1.000000
#
#        ocean_prox_nearbay
# count        10371.000000
# mean             0.109247
# std              0.311964
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max              1.000000

# %% [markdown]
# ### We see that `total_bedrooms` has a few missing values, and it is also very correlated with `total_rooms`. Because of this, it's easiest to remove it from our training set.

# %%
indep_vars.remove("total_bedrooms")

# %% [markdown]
# ### We'll define some helper functions here:
# (1) to calculate MSE, and
# (2) to display the improvement of a GBM on test data as additional trees are constructed.

# %%
def mse(y, y_hat):
    """
    Calculate the MSE of a model given actual and predicted values
    """
    # calculate the residual error for each individual record
    resid = y - y_hat
    # square the residual (hence "squared error")
    sq_resid = resid**2
    # calculate the sum of squared errors
    SSR = sum(sq_resid)
    # divide by the number of records to get the mean squared error
    MSE = SSR / y.shape[0]
    return MSE

def gbm_progress(model_name, X_test, y_test):
    """
    Plot the 'progress' of a GBM on a test set to assess robustness
    """
    test_error = np.zeros_like(model_name.train_score_)
    for idx, y_ in enumerate(model_name.staged_predict(X_test)):
        test_error[idx] = np.mean((y_test - y_)**2)

    plot_idx = np.arange(model_name.train_score_.shape[0])
    ax = subplots(figsize=(8,8))[1]
    ax.plot(plot_idx,
            model_name.train_score_,
            'b',
            label='Training')
    ax.plot(plot_idx,
            test_error,
            'r',
            label='Test')
    ax.legend();

# %% [markdown]
# ### Build a basic GBM first.

# %%
# Documentation: https://scikit-learn.org/dev/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html

gbm_basic = GBR(learning_rate=0.1,
               n_estimators=250,
               max_depth=10,
               min_samples_split=2,
               subsample=1,
               random_state=seed)

gbm_basic.fit(X_train[indep_vars], y_train)
# Out:
# GradientBoostingRegressor(max_depth=10, n_estimators=250, random_state=5151,
#                           subsample=1)

# %%
y_hat_basic = gbm_basic.predict(X_test[indep_vars])

mse_basic = mse(y_test, y_hat_basic)
print('test mse: ',mse_basic)
# Out:
# test mse:  2522992630.270557

# %% [markdown]
# ### When we plot the performance of the model on training and test data, we see that performance no longer improves after a certain number of trees (in this case, between 50-100 trees).

# %%
gbm_progress(gbm_basic, X_test[indep_vars], y_test)

# %% [markdown]
# ### Now you'll have the chance to choose optimal hyperparameters to build a better GBM.
# Once the candidate hyperparameters are chosen, use 5-fold cross-validation to decide which collection of hyperparameters are best.

# %%
def get_best_gbm(X, y, results_path="gridsearch_results.pkl", force_retrain=False):
    """
    Runs GridSearchCV OR loads precomputed results if available.

    Parameters:
        X, y : training data
        results_path : where results are saved
        force_retrain : if True, ignore saved file and rerun

    Returns:
        best_model : fitted model
        best_params : dict
    """

    # Fast Version: load existing results
    if os.path.exists(results_path) and not force_retrain:
        data = joblib.load(results_path)
        print("Loaded precomputed GridSearchCV results.")
        return data["best_model"], data["best_params"]

    # Slow Version: run grid search via cross-validation
    print("Running GridSearchCV...")

    ## Define model
    gbm_cv = GBR(random_state=seed)

    ## Define hyperparameter grid. Choose between 1 and 4 values to test for each one.
    #fillin
    param_grid = {
        "n_estimators": [100, 200, 300],
        "learning_rate": [0.01, 0.1, 0.2],
        "max_depth": [3, 5, 7],
        "min_samples_leaf": [1, 2, 4],
        "subsample": [0.8, 0.9, 1.0]
    }

    grid_search = GridSearchCV(
        estimator=gbm_cv,
        param_grid=param_grid,
        cv=5,                               # number of folds
        scoring="neg_mean_squared_error",   # how we evaluate which model is best
        n_jobs=-1,                          # use all available cores
        verbose=3
    )

    grid_search.fit(X, y)

    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    ## Save results. Gradescope will use this file instead of rerunning the grid search.
    joblib.dump({
        "best_model": best_model,
        "best_params": best_params,
        "cv_results": grid_search.cv_results_
    }, results_path)

    print(f"Saved results to {results_path}")

    return best_model, best_params

# %%
# Identify best model
best_model, best_params = get_best_gbm(X_train[indep_vars], y_train, force_retrain=False)

print("Best parameters:")
print(best_params)
# Out:
# Running GridSearchCV...
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-6797522856.180 total time=   2.4s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-6733134659.681 total time=   2.4s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-6367646532.290 total time=   2.4s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-6369494040.913 total time=   2.4s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-6113040918.974 total time=   2.4s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-6733248764.646 total time=   2.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-6113498185.888 total time=   2.6s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-6798048172.052 total time=   2.6s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-6378982206.245 total time=   2.7s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-6374558391.264 total time=   2.8s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-6121222149.035 total time=   2.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-6735197098.795 total time=   3.0s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-6816095172.474 total time=   3.0s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-6383373775.140 total time=   2.9s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-6383952151.147 total time=   3.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-5278360433.686 total time=   5.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-4764004967.284 total time=   5.3s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-4992546941.510 total time=   5.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-4973317925.276 total time=   5.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-5301654197.837 total time=   5.4s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-5294108561.119 total time=   5.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-4761468476.359 total time=   5.6s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-5331865673.253 total time=   5.7s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-5011679322.328 total time=   5.8s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-5000139872.799 total time=   5.6s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-5298534892.736 total time=   5.9s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-5339977622.085 total time=   5.9s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-4771071281.401 total time=   5.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-5014713394.364 total time=   5.9s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-5016222751.568 total time=   6.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-4675577523.122 total time=   7.6s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-4170241684.660 total time=   7.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-4630378525.010 total time=   7.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-4457432721.698 total time=   7.0s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-4373108111.953 total time=   7.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-4655954869.593 total time=   7.6s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-4174343695.901 total time=   7.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-4655370872.393 total time=   7.6s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-4442731341.606 total time=   7.6s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-6733134659.681 total time=   2.3s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-4383683196.530 total time=   7.5s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-6113040918.974 total time=   2.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-6797522856.180 total time=   2.3s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-6367646532.290 total time=   2.3s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-4706163300.883 total time=   8.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-6369494040.913 total time=   2.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-4181433605.213 total time=   8.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-4687554724.968 total time=   8.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-6733248764.646 total time=   2.6s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-4485434661.404 total time=   8.3s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-4400900856.759 total time=   8.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-6113498185.888 total time=   2.6s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-6798048172.052 total time=   2.6s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-6378982206.245 total time=   2.7s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-6374558391.264 total time=   2.6s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-6735197098.795 total time=   2.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-6121222149.035 total time=   2.8s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-6816095172.474 total time=   2.8s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-6383952151.147 total time=   2.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-6383373775.140 total time=   2.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-5278186778.101 total time=   4.8s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-4764004967.284 total time=   4.8s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-5301654197.837 total time=   4.9s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-4991460073.397 total time=   4.8s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-4973362619.571 total time=   4.8s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-5288784522.338 total time=   5.2s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-4761468476.359 total time=   5.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-5331315652.395 total time=   5.2s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-5010935180.346 total time=   5.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-5000133148.019 total time=   5.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-5293732990.247 total time=   5.6s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-4771071281.401 total time=   5.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-5340101540.109 total time=   5.5s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-5014876735.427 total time=   5.6s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-5014719446.327 total time=   5.5s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-4679114110.020 total time=   6.9s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-4169968128.301 total time=   6.9s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-4629071377.854 total time=   7.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-4458176279.204 total time=   6.8s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-4371855852.649 total time=   6.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-4670859765.843 total time=   7.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-4174126342.080 total time=   7.6s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-4656698037.449 total time=   7.7s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-4451598463.374 total time=   7.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-6733134659.681 total time=   2.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-6113276841.792 total time=   2.6s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-4381942493.378 total time=   8.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-6797261645.182 total time=   2.8s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-4702119283.702 total time=   8.9s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-4684777786.694 total time=   8.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-4181700347.794 total time=   9.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-6367646532.290 total time=   2.7s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-6369265282.630 total time=   2.7s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-4482406044.337 total time=   8.8s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-6733248764.646 total time=   2.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-4402395723.492 total time=   8.9s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-6113259543.134 total time=   2.8s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-6798048172.052 total time=   2.8s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-6378982206.245 total time=   2.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-6374558391.264 total time=   2.9s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-6121222149.035 total time=   3.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-6735197098.795 total time=   3.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-6816095172.474 total time=   2.9s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-6383952151.147 total time=   2.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-6383373775.140 total time=   2.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-5278339859.367 total time=   5.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-4763993804.627 total time=   5.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-5303166427.862 total time=   5.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-4992092894.209 total time=   5.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-4972764035.770 total time=   5.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-5288696206.583 total time=   5.6s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-4761934651.071 total time=   5.6s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-5331555775.397 total time=   5.6s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-5010541590.678 total time=   5.7s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-5000050277.692 total time=   5.6s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-5293653017.413 total time=   5.8s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-4771071281.401 total time=   5.8s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-5339916434.656 total time=   5.8s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-5014684289.270 total time=   5.8s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-5013609841.180 total time=   5.7s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-4677502785.992 total time=   7.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-4167874521.888 total time=   6.8s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-4641314963.236 total time=   7.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-4455623601.930 total time=   6.8s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-4365568963.761 total time=   6.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-4665561790.857 total time=   7.5s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-4180826410.243 total time=   7.6s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-4650973720.190 total time=   7.5s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-4449736603.848 total time=   7.6s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-4376421253.712 total time=   7.5s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-5802303597.786 total time=   3.7s
# [CV 1/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-4701026002.763 total time=   8.1s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-5339346815.658 total time=   3.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-4179852045.051 total time=   8.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-4676774756.216 total time=   8.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-4474967134.850 total time=   8.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-5919672544.986 total time=   3.8s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-5589638749.446 total time=   3.8s
# [CV 5/5] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-4388714999.748 total time=   8.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-5602675322.443 total time=   3.7s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-5822926321.859 total time=   4.1s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-5339369368.131 total time=   4.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-5914881443.850 total time=   4.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-5590790251.626 total time=   4.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-5617739635.099 total time=   4.1s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-5831288540.873 total time=   4.4s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-5359679210.736 total time=   4.4s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-5918071515.126 total time=   4.4s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-5592262084.722 total time=   4.4s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-5628765522.937 total time=   4.4s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-4230904320.683 total time=   7.4s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-3881814215.926 total time=   7.4s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-4274621689.004 total time=   7.5s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-4087676366.185 total time=   7.4s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-4026803266.316 total time=   7.5s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-4235442428.292 total time=   8.2s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-3901221314.180 total time=   8.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-4254689679.172 total time=   8.3s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-4092928272.750 total time=   8.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-4046278227.193 total time=   8.1s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-4256656439.773 total time=   8.8s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-3929276615.552 total time=   8.8s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-4313181067.896 total time=   8.9s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-4116594491.844 total time=   8.8s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-4074695753.111 total time=   8.9s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-3629244423.670 total time=  11.0s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-3337273972.722 total time=  11.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-3575567349.400 total time=  11.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-3516988500.661 total time=  11.3s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-3435077115.564 total time=  11.1s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-3640415765.656 total time=  12.3s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-3356215263.839 total time=  12.4s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-3578360214.469 total time=  12.2s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-3535885973.954 total time=  12.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-5801960381.440 total time=   3.7s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-3470086149.395 total time=  12.8s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-5338064996.801 total time=   4.5s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-3675624931.616 total time=  14.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-5894691073.370 total time=   4.8s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-3355716200.180 total time=  14.6s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-3627100067.648 total time=  14.5s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-5592839389.805 total time=   4.3s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-5584457672.636 total time=   4.3s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-3585948247.967 total time=  14.6s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-5822322768.703 total time=   4.3s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-5339192285.194 total time=   4.3s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-3505253924.535 total time=  14.6s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-5900280129.944 total time=   4.2s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-5576757280.967 total time=   4.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-5616465390.791 total time=   4.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-5834404036.344 total time=   4.6s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-5363580298.650 total time=   4.5s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-5899415382.813 total time=   4.6s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-5577258933.188 total time=   4.6s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-5630932042.310 total time=   4.7s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-4237672151.736 total time=   7.8s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-3883022052.745 total time=   7.9s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-4260196077.289 total time=   7.8s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-4083097847.413 total time=   7.9s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-4029932909.200 total time=   7.7s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-4249990153.047 total time=   8.6s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-3895681678.021 total time=   8.6s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-4239091500.839 total time=   8.5s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-4087847047.836 total time=   8.3s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-4049875275.228 total time=   8.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-4263429373.754 total time=   8.9s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-3918851847.443 total time=   8.9s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-4298327026.305 total time=   9.0s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-4104821524.659 total time=   8.9s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-4091967419.113 total time=   9.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-3619291422.347 total time=  11.4s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-3337525075.279 total time=  11.3s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-3543193473.349 total time=  11.3s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-3512405502.529 total time=  11.3s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-3438147139.514 total time=  11.7s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-3650217533.379 total time=  13.2s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-3349929933.262 total time=  13.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-3558190606.279 total time=  13.3s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-3526518972.378 total time=  13.6s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-5803369601.071 total time=   4.4s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-5323808543.534 total time=   3.9s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-3490145112.653 total time=  14.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-5886366932.309 total time=   4.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-3670410178.177 total time=  15.2s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-3358756388.444 total time=  14.8s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-3617881249.292 total time=  14.8s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-5586709199.613 total time=   3.8s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-5586656167.962 total time=   3.8s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-3570292426.508 total time=  14.3s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-5823920887.567 total time=   4.2s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-5329859841.777 total time=   4.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-5903042012.789 total time=   4.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-3501910166.994 total time=  14.5s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-5584087505.826 total time=   4.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-5605769959.671 total time=   4.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-5827775786.794 total time=   4.6s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-5359911315.745 total time=   4.5s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-5907639880.535 total time=   4.6s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-5587577328.676 total time=   4.5s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-5615884886.589 total time=   4.5s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-4225090341.602 total time=   7.6s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-3862616757.079 total time=   7.5s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-4248053465.244 total time=   7.5s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-4079954764.421 total time=   7.5s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-4031364864.059 total time=   7.5s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-4240091000.487 total time=   8.2s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-3885878491.675 total time=   8.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-4237778163.809 total time=   8.3s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-4086699932.677 total time=   8.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-4042307550.007 total time=   8.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-4264819577.507 total time=   8.9s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-3919683616.098 total time=   8.9s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-4304409050.773 total time=   8.9s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-4110011802.656 total time=   8.9s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-4079345667.463 total time=   8.9s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-3625026302.523 total time=  10.9s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-3319543316.521 total time=  11.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-3544075486.155 total time=  11.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-3508410365.140 total time=  11.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-3442542811.534 total time=  11.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-3636434400.541 total time=  12.4s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-3338703873.029 total time=  12.5s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-3558347884.121 total time=  12.6s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-3519837465.739 total time=  12.6s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-5028463782.299 total time=   5.3s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-3477776579.351 total time=  12.4s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-4716474814.192 total time=   5.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-3663448721.363 total time=  13.5s
# [CV 2/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-3343649010.105 total time=  13.5s
# [CV 3/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-3595806246.050 total time=  13.5s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-5125740793.641 total time=   5.2s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-4903291633.498 total time=   5.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-3562126504.462 total time=  13.5s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-4883533090.673 total time=   5.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-3500568151.168 total time=  13.4s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-5081861060.601 total time=   5.8s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-4733319486.580 total time=   5.9s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-5136427429.728 total time=   5.8s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-4908975586.619 total time=   5.8s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=0.9;, score=-4915092622.868 total time=   5.8s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-5120798603.231 total time=   6.3s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-4764167572.957 total time=   6.2s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-5186638095.846 total time=   6.3s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-4911103862.896 total time=   6.3s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-4918291165.925 total time=   6.2s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-3461268313.987 total time=  10.5s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-3317487962.372 total time=  10.6s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-3475838368.659 total time=  10.7s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-3366519013.689 total time=  10.6s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-3343720316.888 total time=  10.7s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-3489382155.702 total time=  11.8s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-3333870932.896 total time=  11.9s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-3493251492.510 total time=  11.8s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-3378010407.820 total time=  11.7s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-3382052579.353 total time=  11.9s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-3514475569.005 total time=  12.7s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-3384378551.559 total time=  12.8s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-3512202857.623 total time=  12.8s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-3402430416.867 total time=  12.9s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-3410702174.128 total time=  12.9s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-2974187721.880 total time=  15.8s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-2888221096.645 total time=  16.1s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-2910112041.054 total time=  16.5s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-2887632292.875 total time=  16.3s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-2852857005.570 total time=  16.4s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-2993613771.301 total time=  17.9s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-2905659197.979 total time=  18.1s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-2915690924.620 total time=  18.2s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-2895164094.785 total time=  18.2s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-5023859579.658 total time=   5.3s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-2883145118.086 total time=  17.8s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-4710367995.225 total time=   5.3s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-5101535209.432 total time=   5.5s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-3014705252.475 total time=  19.1s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-2930556037.108 total time=  19.1s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-2942072646.158 total time=  18.9s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-4895735799.652 total time=   5.4s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-4874033196.840 total time=   5.4s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-5076260069.450 total time=   5.6s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-2950274399.119 total time=  19.1s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-4740162998.724 total time=   5.7s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-2900773691.032 total time=  19.0s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-5110859539.305 total time=   5.6s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-4910978910.950 total time=   5.7s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-4912062321.422 total time=   5.7s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-5113914684.810 total time=   6.2s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-4760049813.877 total time=   6.2s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-5175397539.061 total time=   6.2s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-4926433020.143 total time=   6.2s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-4918794024.989 total time=   6.2s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-3468966324.179 total time=  10.3s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-3324311886.403 total time=  10.2s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-3456452291.776 total time=  10.1s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-3367471660.415 total time=  10.3s
# [CV 5/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-3335508224.076 total time=  10.2s
# [CV 1/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-3489297506.576 total time=  11.4s
# [CV 2/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-3347934968.711 total time=  11.3s
# [CV 3/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-3488401504.263 total time=  11.6s
# [CV 4/5] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-3387203945.025 total time=  11.5s
# ...
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-2294735318.780 total time=  10.8s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-2432519167.428 total time=  10.7s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=0.9;, score=-2389484695.127 total time=  10.8s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-2524722905.060 total time=  11.7s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-2525763511.331 total time=  12.1s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-2246318113.976 total time=  12.1s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-2489451577.138 total time=  12.4s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-2376996232.080 total time=  12.6s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-2624088565.495 total time=  15.5s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-2546845075.670 total time=  15.3s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-2343940004.980 total time=  15.1s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-2407090122.513 total time=  15.2s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.8;, score=-2414835786.772 total time=  14.7s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-2594204091.626 total time=  16.4s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-2578489724.683 total time=  16.1s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-2281715921.044 total time=  16.1s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-2421177509.850 total time=  16.1s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-2589605690.695 total time=   4.7s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=0.9;, score=-2399841147.592 total time=  16.0s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-2592926507.835 total time=   4.9s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-2347068559.913 total time=   4.9s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-2523427332.634 total time=  17.4s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-2536888062.169 total time=  17.4s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-2455312804.943 total time=   4.8s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-2244772011.001 total time=  17.4s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.8;, score=-2442838508.079 total time=   4.8s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-2663862428.972 total time=   5.3s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-2525604976.729 total time=   5.3s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-2495700887.302 total time=  17.3s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=1, n_estimators=300, subsample=1.0;, score=-2361116614.018 total time=  17.2s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-2366503066.998 total time=   5.3s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-2420797288.509 total time=   5.3s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=0.9;, score=-2430316497.950 total time=   5.3s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-2568433474.563 total time=   5.8s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-2565798069.586 total time=   5.8s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-2336837433.422 total time=   5.9s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-2365348857.075 total time=   5.8s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=100, subsample=1.0;, score=-2311032018.788 total time=   5.7s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-2602976877.597 total time=   9.6s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-2638478578.584 total time=   9.5s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-2311454069.887 total time=   9.5s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-2442772487.288 total time=   9.5s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.8;, score=-2397760160.686 total time=   9.5s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-2664312419.514 total time=  10.5s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-2529193820.965 total time=  10.5s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-2332058825.930 total time=  10.6s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-2390100803.516 total time=  10.5s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=0.9;, score=-2428690851.647 total time=  10.6s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-2545516122.894 total time=  11.6s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-2532881236.443 total time=  11.5s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-2312279262.666 total time=  11.7s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-2354410842.439 total time=  11.9s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=200, subsample=1.0;, score=-2290922434.870 total time=  11.9s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-2611036107.879 total time=  14.9s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-2651463815.201 total time=  14.7s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-2315008986.777 total time=  14.9s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-2436811535.789 total time=  14.7s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=0.8;, score=-2406232136.231 total time=  14.9s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-2662561710.588 total time=  16.5s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-2529263650.074 total time=  16.4s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-2322140196.717 total time=  16.5s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-2387663867.565 total time=  16.5s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-2546047684.230 total time=   4.8s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=0.9;, score=-2437996238.846 total time=  16.4s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-2534574756.205 total time=   4.9s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-2370234777.279 total time=   5.0s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-2563908629.514 total time=  18.0s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-2542805205.262 total time=  18.1s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-2436469105.251 total time=   4.8s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-2307034825.123 total time=  18.0s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=0.8;, score=-2421155113.374 total time=   4.8s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-2636797349.454 total time=   5.3s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-2349543028.451 total time=  17.6s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-2539381483.065 total time=   5.3s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=2, n_estimators=300, subsample=1.0;, score=-2280166286.736 total time=  17.5s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-2226949285.931 total time=   5.4s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-2504929759.962 total time=   5.3s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=0.9;, score=-2395681348.421 total time=   5.4s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-2496421824.095 total time=   5.9s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-2470669290.471 total time=   5.8s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-2273721524.946 total time=   6.2s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-2323325596.475 total time=   6.2s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=100, subsample=1.0;, score=-2358409750.433 total time=   6.3s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-2557647546.020 total time=  10.0s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-2553702813.638 total time=  10.1s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-2362890703.247 total time=  10.2s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-2412869052.289 total time=  10.1s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=0.8;, score=-2434507527.750 total time=  10.1s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-2616798367.770 total time=  10.8s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-2517588751.276 total time=  10.8s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-2229943876.365 total time=  10.7s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-2500280368.156 total time=  10.9s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=0.9;, score=-2343678870.440 total time=  10.9s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-2499963792.657 total time=  12.0s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-2497370699.394 total time=  12.0s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-2255291850.852 total time=  12.1s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-2317333937.779 total time=  12.3s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=200, subsample=1.0;, score=-2355305916.277 total time=  12.3s
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-2550803958.169 total time=  16.2s
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-2549783399.838 total time=  15.7s
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-2380956462.232 total time=  16.2s
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-2398990019.289 total time=  16.0s
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=0.8;, score=-2429653700.321 total time=16.7min
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-2626087956.697 total time=16.7min
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-2212370615.247 total time=16.7min
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-2519092389.493 total time=16.7min
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-2513567841.503 total time=27.0min
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=0.9;, score=-2328787584.341 total time=27.0min
# [CV 1/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-2494622362.728 total time=27.1min
# [CV 2/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-2519806611.360 total time=27.1min
# [CV 3/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-2244538578.916 total time=10.7min
# [CV 4/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-2319026381.615 total time=10.7min
# [CV 5/5] END learning_rate=0.2, max_depth=7, min_samples_leaf=4, n_estimators=300, subsample=1.0;, score=-2359293751.945 total time=10.6min
# Saved results to gridsearch_results.pkl
# Best parameters:
# {'learning_rate': 0.1, 'max_depth': 7, 'min_samples_leaf': 4, 'n_estimators': 300, 'subsample': 0.8}

# %% [markdown]
# ### Your grade on this assignment will be partially determined by the mean squared error on a separate holdout set. You can approximate this using the test set.

# %%
# Evaluate on test set 
y_pred = best_model.predict(X_test[indep_vars])
mse_best = mse(y_test, y_pred)

print("Test MSE:", mse_best)
# Out:
# Test MSE: 2240916660.8692746
