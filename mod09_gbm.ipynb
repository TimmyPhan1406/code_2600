# %%
# packages
import os
import joblib
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import GradientBoostingRegressor as GBR
from sklearn.model_selection import GridSearchCV

# set seed
seed = 5151

# %% [markdown]
# ### You'll need the California housing data (CAhousing.csv) to complete this exercise. Your goal is to predict the median house value.

# %%
CAhousing = pd.read_csv('data/CAhousing.csv')
CAhousing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -120.45     34.66                 7.0       3329.0           504.0
# 1    -114.64     34.83                10.0       2502.0           573.0
# 2    -117.24     32.74                43.0       2216.0           375.0
# 3    -122.43     37.76                52.0       3771.0          1017.0
# 4    -118.02     34.13                34.0       1966.0           319.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0      1462.0       452.0         4.7875            198300.0      NEAR OCEAN
# 1      1152.0       481.0         1.7062             86800.0          INLAND
# 2       918.0       388.0         5.5289            297700.0      NEAR OCEAN
# 3      1575.0       921.0         3.5655            427300.0        NEAR BAY
# 4       980.0       297.0         7.7307            429000.0          INLAND

# %%
CAhousing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
CAhousing.shape
# Out:
# (15480, 10)

# %% [markdown]
# ### There is a single categorical variable in this dataset that we will convert to a series of binary variables.

# %%
CAhousing['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6857
# INLAND        4933
# NEAR OCEAN    1974
# NEAR BAY      1712
# ISLAND           4
# Name: count, dtype: int64

# %%
# create binary variables for levels which have enough records, using '<1H OCEAN' as base.
CAhousing['ocean_prox_inland'] = (CAhousing.ocean_proximity == 'INLAND').astype(int)
CAhousing['ocean_prox_nearocean'] = (CAhousing.ocean_proximity == 'NEAR OCEAN').astype(int)
CAhousing['ocean_prox_nearbay'] = (CAhousing.ocean_proximity == 'NEAR BAY').astype(int)

# check for intended outcome
print(CAhousing['ocean_prox_inland'].value_counts())
print(CAhousing['ocean_prox_nearocean'].value_counts())
print(CAhousing['ocean_prox_nearbay'].value_counts())
# Out:
# ocean_prox_inland
# 0    10547
# 1     4933
# Name: count, dtype: int64
# ocean_prox_nearocean
# 0    13506
# 1     1974
# Name: count, dtype: int64
# ocean_prox_nearbay
# 0    13768
# 1     1712
# Name: count, dtype: int64

# %%
indep_vars = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 
              'total_bedrooms', 'population', 'households', 'median_income', 
              'ocean_prox_inland', 'ocean_prox_nearocean', 'ocean_prox_nearbay']

X = CAhousing[indep_vars]
y = CAhousing['median_house_value']

# %%
X_train, X_test, y_train, y_test, Train, Test = train_test_split(X, y, CAhousing, 
                                                                 random_state = seed, 
                                                                 test_size = 0.33, 
                                                                 shuffle = True)

# %%
X_train.corr().style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_063d4_row0_col0, #T_063d4_row1_col1, #T_063d4_row2_col2, #T_063d4_row3_col3, #T_063d4_row4_col4, #T_063d4_row5_col5, #T_063d4_row6_col6, #T_063d4_row7_col7, #T_063d4_row8_col8, #T_063d4_row9_col9, #T_063d4_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_063d4_row0_col1, #T_063d4_row1_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_063d4_row0_col2, #T_063d4_row2_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_063d4_row0_col3, #T_063d4_row3_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_063d4_row0_col4, #T_063d4_row4_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_063d4_row0_col5, #T_063d4_row5_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_063d4_row0_col6, #T_063d4_row6_col0, #T_063d4_row7_col10, #T_063d4_row10_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_063d4_row0_col7, #T_063d4_row3_col9, #T_063d4_row7_col0, #T_063d4_row9_col3 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_063d4_row0_col8, #T_063d4_row1_col4, #T_063d4_row4_col1, #T_063d4_row5_col10, #T_063d4_row8_col0, #T_063d4_row10_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_063d4_row0_col9, #T_063d4_row9_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_063d4_row0_col10, #T_063d4_row10_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_063d4_row1_col2, #T_063d4_row2_col1, #T_063d4_row2_col9, #T_063d4_row3_col8, #T_063d4_row8_col3, #T_063d4_row9_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_063d4_row1_col3, #T_063d4_row3_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_063d4_row1_col5, #T_063d4_row5_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_063d4_row1_col6, #T_063d4_row6_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_063d4_row1_col7, #T_063d4_row7_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_063d4_row1_col8, #T_063d4_row8_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_063d4_row1_col9, #T_063d4_row9_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_063d4_row1_col10, #T_063d4_row10_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_063d4_row2_col3, #T_063d4_row3_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_063d4_row2_col4, #T_063d4_row4_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_063d4_row2_col5, #T_063d4_row5_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_063d4_row2_col6, #T_063d4_row6_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_063d4_row2_col7, #T_063d4_row7_col2, #T_063d4_row9_col10, #T_063d4_row10_col9 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_063d4_row2_col8, #T_063d4_row7_col8, #T_063d4_row8_col2, #T_063d4_row8_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_063d4_row2_col10, #T_063d4_row10_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_063d4_row3_col4, #T_063d4_row4_col3 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_063d4_row3_col5, #T_063d4_row5_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_063d4_row3_col6, #T_063d4_row6_col3 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_063d4_row3_col7, #T_063d4_row7_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_063d4_row3_col10, #T_063d4_row5_col8, #T_063d4_row8_col5, #T_063d4_row10_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_063d4_row4_col5, #T_063d4_row5_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_063d4_row4_col6, #T_063d4_row6_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_063d4_row4_col7, #T_063d4_row4_col8, #T_063d4_row5_col9, #T_063d4_row7_col4, #T_063d4_row8_col4, #T_063d4_row9_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_063d4_row4_col9, #T_063d4_row5_col7, #T_063d4_row6_col9, #T_063d4_row7_col5, #T_063d4_row9_col4, #T_063d4_row9_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_063d4_row4_col10, #T_063d4_row6_col10, #T_063d4_row10_col4, #T_063d4_row10_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_063d4_row5_col6, #T_063d4_row6_col5 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_063d4_row6_col7, #T_063d4_row7_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_063d4_row6_col8, #T_063d4_row8_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_063d4_row7_col9, #T_063d4_row9_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_063d4_row8_col9, #T_063d4_row9_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_063d4_row8_col10, #T_063d4_row10_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# </style>
# <table id="T_063d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_063d4_level0_col0" class="col_heading level0 col0" >longitude</th>
#       <th id="T_063d4_level0_col1" class="col_heading level0 col1" >latitude</th>
#       <th id="T_063d4_level0_col2" class="col_heading level0 col2" >housing_median_age</th>
#       <th id="T_063d4_level0_col3" class="col_heading level0 col3" >total_rooms</th>
#       <th id="T_063d4_level0_col4" class="col_heading level0 col4" >total_bedrooms</th>
#       <th id="T_063d4_level0_col5" class="col_heading level0 col5" >population</th>
#       <th id="T_063d4_level0_col6" class="col_heading level0 col6" >households</th>
#       <th id="T_063d4_level0_col7" class="col_heading level0 col7" >median_income</th>
#       <th id="T_063d4_level0_col8" class="col_heading level0 col8" >ocean_prox_inland</th>
#       <th id="T_063d4_level0_col9" class="col_heading level0 col9" >ocean_prox_nearocean</th>
#       <th id="T_063d4_level0_col10" class="col_heading level0 col10" >ocean_prox_nearbay</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_063d4_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_063d4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_063d4_row0_col1" class="data row0 col1" >-0.924779</td>
#       <td id="T_063d4_row0_col2" class="data row0 col2" >-0.118552</td>
#       <td id="T_063d4_row0_col3" class="data row0 col3" >0.044445</td>
#       <td id="T_063d4_row0_col4" class="data row0 col4" >0.067878</td>
#       <td id="T_063d4_row0_col5" class="data row0 col5" >0.095517</td>
#       <td id="T_063d4_row0_col6" class="data row0 col6" >0.056249</td>
#       <td id="T_063d4_row0_col7" class="data row0 col7" >-0.001915</td>
#       <td id="T_063d4_row0_col8" class="data row0 col8" >-0.068406</td>
#       <td id="T_063d4_row0_col9" class="data row0 col9" >0.047632</td>
#       <td id="T_063d4_row0_col10" class="data row0 col10" >-0.471177</td>
#     </tr>
#     <tr>
#       <th id="T_063d4_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_063d4_row1_col0" class="data row1 col0" >-0.924779</td>
#       <td id="T_063d4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_063d4_row1_col2" class="data row1 col2" >0.017276</td>
#       <td id="T_063d4_row1_col3" class="data row1 col3" >-0.034301</td>
#       <td id="T_063d4_row1_col4" class="data row1 col4" >-0.064393</td>
#       <td id="T_063d4_row1_col5" class="data row1 col5" >-0.104774</td>
#       <td id="T_063d4_row1_col6" class="data row1 col6" >-0.070660</td>
#       <td id="T_063d4_row1_col7" class="data row1 col7" >-0.091395</td>
#       <td id="T_063d4_row1_col8" class="data row1 col8" >0.362431</td>
#       <td id="T_063d4_row1_col9" class="data row1 col9" >-0.162865</td>
#       <td id="T_063d4_row1_col10" class="data row1 col10" >0.352288</td>
#     </tr>
#     <tr>
#       <th id="T_063d4_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_063d4_row2_col0" class="data row2 col0" >-0.118552</td>
#       <td id="T_063d4_row2_col1" class="data row2 col1" >0.017276</td>
#       <td id="T_063d4_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_063d4_row2_col3" class="data row2 col3" >-0.356225</td>
#       <td id="T_063d4_row2_col4" class="data row2 col4" >-0.312179</td>
#       <td id="T_063d4_row2_col5" class="data row2 col5" >-0.296755</td>
#       <td id="T_063d4_row2_col6" c

# %%
Train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  10371.000000  10371.000000        10371.000000  10371.000000
# mean    -119.576317     35.648347           28.707646   2631.445569
# std        1.997211      2.140070           12.631120   2173.616930
# min     -124.260000     32.560000            1.000000      8.000000
# 25%     -121.770000     33.940000           18.000000   1454.000000
# 50%     -118.510000     34.260000           29.000000   2126.000000
# 75%     -118.020000     37.730000           37.000000   3127.000000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    10257.000000  10371.000000  10371.000000   10371.000000
# mean       537.541484   1426.518851    500.422524       3.868065
# std        425.582759   1137.463225    388.555637       1.885826
# min          1.000000      5.000000      1.000000       0.499900
# 25%        296.000000    791.000000    282.000000       2.556800
# 50%        435.000000   1163.000000    410.000000       3.534500
# 75%        640.000000   1719.000000    601.000000       4.747400
# max       6445.000000  28566.000000   6082.000000      15.000100
#
#        median_house_value  ocean_prox_inland  ocean_prox_nearocean  \
# count        10371.000000       10371.000000          10371.000000
# mean        206399.612284           0.323787              0.124771
# std         115215.425942           0.467943              0.330475
# min          14999.000000           0.000000              0.000000
# 25%         118750.000000           0.000000              0.000000
# 50%         179800.000000           0.000000              0.000000
# 75%         264000.000000           1.000000              0.000000
# max         500001.000000           1.000000              1.000000
#
#        ocean_prox_nearbay
# count        10371.000000
# mean             0.109247
# std              0.311964
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max              1.000000

# %% [markdown]
# ### We see that `total_bedrooms` has a few missing values, and it is also very correlated with `total_rooms`. Because of this, it's easiest to remove it from our training set.

# %%
indep_vars.remove("total_bedrooms")

# %% [markdown]
# ### We'll define some helper functions here:
# (1) to calculate MSE, and
# (2) to display the improvement of a GBM on test data as additional trees are constructed.

# %%
def mse(y, y_hat):
    """
    Calculate the MSE of a model given actual and predicted values
    """
    # calculate the residual error for each individual record
    resid = y - y_hat
    # square the residual (hence "squared error")
    sq_resid = resid**2
    # calculate the sum of squared errors
    SSR = sum(sq_resid)
    # divide by the number of records to get the mean squared error
    MSE = SSR / y.shape[0]
    return MSE

def gbm_progress(model_name, X_test, y_test):
    """
    Plot the 'progress' of a GBM on a test set to assess robustness
    """
    test_error = np.zeros_like(model_name.train_score_)
    for idx, y_ in enumerate(model_name.staged_predict(X_test)):
        test_error[idx] = np.mean((y_test - y_)**2)

    plot_idx = np.arange(model_name.train_score_.shape[0])
    ax = subplots(figsize=(8,8))[1]
    ax.plot(plot_idx,
            model_name.train_score_,
            'b',
            label='Training')
    ax.plot(plot_idx,
            test_error,
            'r',
            label='Test')
    ax.legend();

# %% [markdown]
# ### Build a basic GBM first.

# %%
# Documentation: https://scikit-learn.org/dev/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html

gbm_basic = GBR(learning_rate=0.1,
               n_estimators=250,
               max_depth=10,
               min_samples_split=2,
               subsample=1,
               random_state=seed)

gbm_basic.fit(X_train[indep_vars], y_train)
# Out:
# GradientBoostingRegressor(max_depth=10, n_estimators=250, random_state=5151,
#                           subsample=1)

# %%
y_hat_basic = gbm_basic.predict(X_test[indep_vars])

mse_basic = mse(y_test, y_hat_basic)
print('test mse: ',mse_basic)
# Out:
# test mse:  2522992630.270557

# %% [markdown]
# ### When we plot the performance of the model on training and test data, we see that performance no longer improves after a certain number of trees (in this case, between 50-100 trees).

# %%
gbm_progress(gbm_basic, X_test[indep_vars], y_test)

# %% [markdown]
# ### Now you'll have the chance to choose optimal hyperparameters to build a better GBM.
# Once the candidate hyperparameters are chosen, use 5-fold cross-validation to decide which collection of hyperparameters are best.

# %%
def get_best_gbm(X, y, results_path="gridsearch_results.pkl", force_retrain=False):
    """
    Runs GridSearchCV OR loads precomputed results if available.

    Parameters:
        X, y : training data
        results_path : where results are saved
        force_retrain : if True, ignore saved file and rerun

    Returns:
        best_model : fitted model
        best_params : dict
    """

    # Fast Version: load existing results
    if os.path.exists(results_path) and not force_retrain:
        data = joblib.load(results_path)
        print("Loaded precomputed GridSearchCV results.")
        return data["best_model"], data["best_params"]

    # Slow Version: run grid search via cross-validation
    print("Running GridSearchCV...")

    ## Define model
    gbm_cv = GBR(random_state=seed)

    ## Define hyperparameter grid. Choose between 1 and 4 values to test for each one.
    #fillin
    param_grid = {
        "n_estimators": [100, 200, 400],
        "learning_rate": [0.03, 0.05, 0.1],
        "max_depth": [2, 3, 4],
        "min_samples_leaf": [3, 5, 10],
        "subsample": [0.6, 0.8, 1.0]
    }

    grid_search = GridSearchCV(
        estimator=gbm_cv,
        param_grid=param_grid,
        cv=5,                               # number of folds
        scoring="neg_mean_squared_error",   # how we evaluate which model is best
        n_jobs=-1,                          # use all available cores
        verbose=3
    )

    grid_search.fit(X, y)

    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    ## Save results. Gradescope will use this file instead of rerunning the grid search.
    joblib.dump({
        "best_model": best_model,
        "best_params": best_params,
        "cv_results": grid_search.cv_results_
    }, results_path)

    print(f"Saved results to {results_path}")

    return best_model, best_params

# %%
# Identify best model
best_model, best_params = get_best_gbm(X_train[indep_vars], y_train, force_retrain=False)

print("Best parameters:")
print(best_params)
# Out:
# Running GridSearchCV...
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-5010316246.141 total time=   1.1s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-5375953979.387 total time=   1.1s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-4841593733.992 total time=   1.1s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-5357868358.522 total time=   1.1s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-5076798185.472 total time=   1.2s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-5386939591.230 total time=   1.4s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-4855089166.434 total time=   1.4s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-5400386279.321 total time=   1.5s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-5085252539.264 total time=   1.7s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-5022914976.444 total time=   1.8s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-5400526000.318 total time=   1.9s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-5413529596.834 total time=   1.9s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-4883833356.815 total time=   2.1s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-5024928628.076 total time=   1.8s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-5115042083.167 total time=   2.1s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-4441883659.593 total time=   2.8s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-3959266419.214 total time=   2.7s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-4375330715.980 total time=   2.7s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-4134453059.769 total time=   2.7s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-4227936145.919 total time=   2.7s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-4007345804.277 total time=   3.2s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-4472771681.437 total time=   3.4s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-4394842004.206 total time=   3.3s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-4250669304.555 total time=   3.2s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-4112458298.376 total time=   3.3s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-4447784695.698 total time=   3.7s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-4013694564.755 total time=   3.7s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-4385920257.714 total time=   3.8s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-4117188608.970 total time=   3.7s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-4236802936.477 total time=   3.9s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-3804035776.359 total time=   5.2s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-3317443587.456 total time=   5.4s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-3615399397.476 total time=   5.3s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-3561888376.694 total time=   5.3s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-3470845519.779 total time=   5.3s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-3810805710.887 total time=   6.5s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-3299457950.833 total time=   6.4s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-3649410067.932 total time=   6.5s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-5375947338.275 total time=   1.3s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-3579922596.681 total time=   6.3s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-3453132474.560 total time=   6.2s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-4844852231.112 total time=   1.3s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-5367429141.550 total time=   1.3s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-5080902488.902 total time=   1.3s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-5006868998.566 total time=   1.3s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-5400386279.321 total time=   1.6s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-3784423335.389 total time=   7.2s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-3311076713.093 total time=   7.3s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-4855333650.512 total time=   1.6s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-3612936097.143 total time=   7.3s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-5385169068.517 total time=   1.6s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-5085252539.264 total time=   1.6s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-5022914976.444 total time=   1.6s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-3544227100.441 total time=   7.2s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-5400526000.318 total time=   1.8s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-4883833356.815 total time=   1.8s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-5413529596.834 total time=   1.9s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-3426332117.094 total time=   7.3s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-5115042083.167 total time=   1.8s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-5024928628.076 total time=   1.8s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-4465832148.477 total time=   2.6s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-3974137144.901 total time=   2.6s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-4383703085.952 total time=   2.5s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-4217683703.767 total time=   2.6s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-4132110673.734 total time=   2.5s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-4472055890.294 total time=   3.2s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-4007091036.697 total time=   3.2s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-4389798424.958 total time=   3.1s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-4249560869.464 total time=   3.1s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-4116883601.305 total time=   3.1s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-4447784695.698 total time=   3.5s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-4013694564.755 total time=   3.6s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-4385920257.714 total time=   3.6s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-4236802936.477 total time=   3.6s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-4112184449.128 total time=   3.5s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-3808212406.376 total time=   5.0s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-3323455119.613 total time=   5.0s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-3617951553.139 total time=   5.1s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-3564557567.726 total time=   5.0s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-3463855035.717 total time=   5.1s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-3809339878.867 total time=   6.2s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-3309245753.264 total time=   6.3s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-3629114667.637 total time=   6.3s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-5380537510.374 total time=   1.3s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-3576789960.096 total time=   6.2s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-4843393353.223 total time=   1.3s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-3450089292.012 total time=   6.3s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-5369640726.336 total time=   1.3s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-5085205202.384 total time=   1.3s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-3782288344.643 total time=   7.2s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-5007402948.578 total time=   1.3s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-5406382737.267 total time=   1.5s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-3311012579.136 total time=   7.2s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-3611208828.582 total time=   7.3s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-4858561647.813 total time=   1.6s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-5388195172.758 total time=   1.6s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-5097801391.777 total time=   1.6s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-5018707107.588 total time=   1.7s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-3544190648.261 total time=   7.3s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-5403270404.888 total time=   2.0s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-4886034472.970 total time=   2.0s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-3410489474.787 total time=   7.5s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-5415825244.144 total time=   2.1s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-5102939739.712 total time=   2.1s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-5024906060.890 total time=   2.1s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-4468573685.450 total time=   2.7s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-3970011698.193 total time=   2.7s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-4383184789.214 total time=   2.7s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-4227107507.720 total time=   2.6s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-4117021347.311 total time=   2.6s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-4507018806.561 total time=   3.2s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-4000165222.366 total time=   3.2s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-4385047332.543 total time=   3.2s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-4247906198.592 total time=   3.3s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-4112809661.211 total time=   3.3s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-4463602602.699 total time=   3.7s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-4025589213.124 total time=   3.7s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-4380107570.058 total time=   3.7s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-4239226553.800 total time=   3.6s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-4114979561.790 total time=   3.6s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-3808123639.537 total time=   5.1s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-3333599735.909 total time=   5.1s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-3633195447.529 total time=   5.0s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-3578353270.398 total time=   5.0s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-3437869967.208 total time=   5.1s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-3797471229.980 total time=   6.2s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-3305066599.297 total time=   6.2s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-3617611821.095 total time=   6.2s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-3577567535.461 total time=   6.2s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-4642409653.384 total time=   1.8s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-3444712735.068 total time=   6.2s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-4146751370.803 total time=   1.9s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-4587510283.555 total time=   2.0s
# [CV 1/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-3773191375.944 total time=   7.5s
# [CV 2/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-3310752325.459 total time=   7.5s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-4421068309.929 total time=   2.3s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-4346321746.511 total time=   2.2s
# [CV 3/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-3625999467.873 total time=   7.7s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-4649773758.012 total time=   2.6s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-4146247425.055 total time=   2.4s
# [CV 4/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-3550481425.613 total time=   8.0s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-4631086821.988 total time=   2.8s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-4435559330.432 total time=   2.8s
# [CV 5/5] END learning_rate=0.03, max_depth=2, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-3411391428.828 total time=   8.1s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-4366884832.853 total time=   2.7s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-4694996698.244 total time=   3.1s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-4174856346.502 total time=   3.4s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-4674546038.876 total time=   3.3s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-4464467429.891 total time=   3.2s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-4380418449.937 total time=   3.1s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-3731448195.238 total time=   4.0s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-3295531355.629 total time=   4.0s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-3583006739.360 total time=   3.9s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-3531620425.842 total time=   3.9s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-3481876740.901 total time=   4.7s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-3742336751.364 total time=   5.6s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-3316506517.490 total time=   5.6s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-3594314378.650 total time=   5.7s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-3576193186.161 total time=   5.9s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-3501871372.121 total time=   6.1s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-3802284929.029 total time=   6.8s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-3374928387.007 total time=   6.9s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-3660433406.317 total time=   6.1s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-3654647718.523 total time=   7.6s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-3538163091.445 total time=   7.6s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-3209781046.859 total time=  10.3s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2858782896.065 total time=  10.0s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2973760302.596 total time=  10.0s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-3075975850.924 total time=   9.9s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2970812877.241 total time=   9.9s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-3176515776.036 total time=  11.4s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2835791522.968 total time=   9.9s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2961436410.150 total time=   9.8s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-4634390328.461 total time=   1.8s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-3077655605.949 total time=   9.1s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2983655518.947 total time=   9.3s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-4127770663.217 total time=   1.8s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-4583080299.445 total time=   1.8s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-3217344278.899 total time=  10.6s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-4434143726.269 total time=   1.9s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-4332789964.868 total time=   1.9s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2853180322.995 total time=  10.6s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-4648955323.858 total time=   2.4s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2989422179.617 total time=  10.8s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-4143014705.839 total time=   2.3s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-4632349716.115 total time=   2.3s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-4434899546.575 total time=   2.3s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-4365900273.771 total time=   2.3s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-3081931991.272 total time=  10.6s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-4174360330.979 total time=   2.6s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-4686928199.774 total time=   2.7s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-4669769951.524 total time=   2.6s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-4383675070.944 total time=   2.6s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-4463526335.967 total time=   2.6s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2975849294.757 total time=  10.6s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-3720000970.122 total time=   3.5s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-3289965917.016 total time=   3.4s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-3544620886.236 total time=   3.6s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-3538523300.016 total time=   3.6s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-3459004116.223 total time=   3.5s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3759370041.754 total time=   4.3s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3328263888.100 total time=   4.3s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3597739429.377 total time=   4.4s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3551709866.985 total time=   4.5s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3483704754.752 total time=   4.7s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-3371382335.529 total time=   5.4s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-3802223708.109 total time=   5.6s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-3657551340.227 total time=   5.4s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-3481814230.352 total time=   5.3s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-3634430112.476 total time=   5.4s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-3205031084.066 total time=   7.6s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-2863188472.759 total time=   7.6s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-2946155606.214 total time=   7.4s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-3081297270.989 total time=   7.4s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-2952236861.876 total time=   7.5s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-3184785311.455 total time=   9.3s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-2811512085.047 total time=   9.2s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-2966427021.510 total time=   9.2s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-4600124142.267 total time=   1.8s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-3074881650.131 total time=   8.8s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-2952457389.606 total time=   8.7s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-4123478988.685 total time=   1.7s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-4577365613.468 total time=   1.8s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-4455337140.789 total time=   1.7s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-4343919302.658 total time=   1.7s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-3222918207.999 total time=  10.3s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-4644219246.134 total time=   2.2s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-2824855218.567 total time=  10.3s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-2987619358.278 total time=  10.3s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-4150408984.161 total time=   2.2s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-4622159460.266 total time=   2.2s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-4450053097.515 total time=   2.2s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-4366882438.586 total time=   2.2s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-3088231297.911 total time=  10.2s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-4696599534.180 total time=   2.6s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-4174878117.854 total time=   2.6s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-4658027161.559 total time=   2.6s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-4477537244.128 total time=   2.6s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-2962608805.651 total time=  10.3s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-4386061330.324 total time=   2.5s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-3710921161.609 total time=   3.6s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-3279833250.397 total time=   3.6s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-3564963596.023 total time=   3.6s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-3567112928.462 total time=   3.7s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-3489907191.321 total time=   3.7s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-3720718346.078 total time=   4.5s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-3294938869.506 total time=   4.5s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-3596299244.790 total time=   4.6s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-3576072551.267 total time=   4.4s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-3461206711.957 total time=   4.5s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-3820405326.757 total time=   5.1s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-3358582065.043 total time=   5.1s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-3659208281.017 total time=   5.1s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-3516245876.554 total time=   5.1s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-3622628891.144 total time=   5.2s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-3180661940.507 total time=   6.8s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-2832322737.686 total time=   6.8s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-2964700701.722 total time=   6.9s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-3115095010.904 total time=   6.9s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-2949914086.406 total time=   7.0s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-3170303079.241 total time=   8.7s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-2963204852.750 total time=   8.7s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-2848738081.065 total time=   8.8s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-3108436274.935 total time=   8.7s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-4065216988.779 total time=   2.2s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-2939916713.402 total time=   8.7s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-3661340815.629 total time=   2.3s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-3968536576.656 total time=   2.3s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-3856690376.844 total time=   2.3s
# [CV 1/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-3227130079.213 total time=  10.1s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=0.6;, score=-3859539241.351 total time=   2.2s
# [CV 2/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-2837605017.786 total time=  10.2s
# [CV 3/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-2994085946.073 total time=  10.1s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-4056351502.986 total time=   2.9s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-3640826915.475 total time=   2.9s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-3988256017.334 total time=   2.9s
# [CV 4/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-3093617529.619 total time=  10.2s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-3966862680.495 total time=   2.9s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=0.8;, score=-3903283773.055 total time=   2.9s
# [CV 5/5] END learning_rate=0.03, max_depth=3, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-2953593544.619 total time=  10.2s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-4153983247.906 total time=   3.4s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-3670186279.566 total time=   3.4s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-4023355547.876 total time=   3.4s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-3965860139.481 total time=   3.4s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=100, subsample=1.0;, score=-3872311072.267 total time=   3.4s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-3197910726.092 total time=   4.4s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-2950677246.507 total time=   4.4s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-3055536885.356 total time=   4.5s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-3059527909.155 total time=   4.5s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.6;, score=-3075096437.151 total time=   4.4s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-3217797197.797 total time=   6.2s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-2874783869.884 total time=   6.1s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-3044929315.475 total time=   6.2s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-3115500104.215 total time=   6.2s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-3061357005.079 total time=   6.4s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-3250711151.063 total time=   7.3s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-2913655955.211 total time=   7.3s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-3090634916.646 total time=   7.5s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-3110061842.789 total time=   6.7s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-3110502203.546 total time=   6.9s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2819671238.276 total time=   9.1s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2614558530.522 total time=   8.9s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2595645542.170 total time=   8.8s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2687163061.131 total time=   8.8s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2671629252.761 total time=   8.9s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2818813882.867 total time=  11.3s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2549906277.983 total time=  11.6s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2569565194.405 total time=  11.6s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-4034809255.309 total time=   2.3s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2706866963.667 total time=  11.4s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2670132757.214 total time=  11.5s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-3663114230.974 total time=   2.3s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-3974518341.338 total time=   2.3s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2819116103.163 total time=  13.4s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-3866678160.676 total time=   2.2s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-3864999671.134 total time=   2.3s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-4070371542.250 total time=   2.9s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2534598205.518 total time=  13.6s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2599730797.783 total time=  13.6s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-3657045835.518 total time=   2.9s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-4009641170.529 total time=   2.9s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-3931302338.308 total time=   2.8s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-3915234939.574 total time=   2.8s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2700878643.970 total time=  13.5s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-4114230334.137 total time=   3.3s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-3667432949.586 total time=   3.3s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-4018849376.662 total time=   3.3s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-3972475468.139 total time=   3.3s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-3847159673.161 total time=   3.3s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2667165202.982 total time=  13.3s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-3205187371.722 total time=   4.3s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-2955595063.579 total time=   4.4s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-3065799064.818 total time=   4.4s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-3085503012.493 total time=   4.4s
# [CV 5/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-3102407823.503 total time=   4.3s
# [CV 1/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3240240663.769 total time=   5.5s
# [CV 2/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-2886539805.332 total time=   5.5s
# [CV 3/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3061414689.848 total time=   5.5s
# [CV 4/5] END learning_rate=0.03, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3102567278.031 total time=   5.8s
# ...
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-2593442055.171 total time=   3.6s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=0.8;, score=-2532110955.821 total time=   3.7s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-2729699014.275 total time=   4.3s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-2441735249.435 total time=   4.3s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-2392918569.238 total time=   4.3s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-2511964667.728 total time=   4.3s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=200, subsample=1.0;, score=-2545901412.115 total time=   4.3s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2555061835.749 total time=   5.8s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2397387323.814 total time=   5.8s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2253759402.068 total time=   5.7s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2364043180.459 total time=   5.7s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.6;, score=-2438784263.397 total time=   5.7s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2540467901.504 total time=   7.4s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2379324932.865 total time=   7.3s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2155884515.237 total time=   7.4s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-2990533169.605 total time=   1.6s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2410496922.797 total time=   7.7s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=0.8;, score=-2397648349.216 total time=   7.5s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-2655913176.731 total time=   1.5s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-2761717056.020 total time=   1.6s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-2893512988.717 total time=   1.5s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2607227303.156 total time=   8.9s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.6;, score=-2715315495.529 total time=   1.5s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2364336457.533 total time=   9.0s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-2918627858.964 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2224354762.352 total time=   9.2s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-2643249559.125 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-2654436655.111 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-2850097179.346 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-2736830783.597 total time=   1.8s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2407918701.113 total time=   9.0s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-2881436525.216 total time=   2.3s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-2636543682.431 total time=   2.2s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-2719379098.554 total time=   2.2s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-2775013438.144 total time=   2.3s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=3, n_estimators=400, subsample=1.0;, score=-2411608551.445 total time=   9.0s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-2771997542.047 total time=   2.2s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-2730185961.810 total time=   3.0s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-2478558345.821 total time=   3.0s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-2449971210.218 total time=   3.1s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-2618293314.339 total time=   2.9s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.6;, score=-2533277905.586 total time=   3.0s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-2628713553.938 total time=   3.7s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-2451351348.918 total time=   3.8s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-2359299358.587 total time=   3.7s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-2628829026.923 total time=   3.7s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-2520348648.402 total time=   3.7s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-2668171440.688 total time=   4.4s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-2431831276.164 total time=   4.4s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-2408010273.617 total time=   4.5s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-2527243665.840 total time=   4.4s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-2561798464.999 total time=   4.4s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-2603358187.425 total time=   5.8s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-2386850196.649 total time=   5.9s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-2252923753.382 total time=   5.9s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-2417603097.189 total time=   5.7s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=0.6;, score=-2411668081.981 total time=   5.9s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-2518473600.607 total time=   7.8s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-2357176105.076 total time=   7.7s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-2186371842.881 total time=   7.8s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-2892036393.997 total time=   1.6s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-2441682463.276 total time=   8.0s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-2662922377.558 total time=   1.4s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=0.8;, score=-2372859883.457 total time=   7.8s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-2769227875.475 total time=   1.5s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-2931973356.657 total time=   1.4s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=0.6;, score=-2741905223.327 total time=   1.4s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-2564719120.304 total time=   9.3s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-2877263408.701 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-2341758584.282 total time=   9.1s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-2308807851.752 total time=   9.2s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-2668331570.306 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-2722776784.938 total time=   2.0s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-2905284187.195 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=0.8;, score=-2788605418.005 total time=   2.0s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-2891371165.273 total time=   2.3s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-2412155823.361 total time=   9.1s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-2605659619.204 total time=   2.4s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-2853177632.029 total time=   2.4s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-2668499413.129 total time=   2.4s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=100, subsample=1.0;, score=-2698104922.653 total time=   2.2s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=5, n_estimators=400, subsample=1.0;, score=-2425830106.525 total time=   9.3s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-2661333674.532 total time=   3.0s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-2508000015.613 total time=   2.9s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-2436814361.652 total time=   2.9s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-2646047569.584 total time=   3.0s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=0.6;, score=-2551713483.194 total time=   2.9s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-2620430905.740 total time=   3.7s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-2500730058.181 total time=   3.8s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-2407959155.899 total time=   3.7s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-2680344013.099 total time=   3.8s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=0.8;, score=-2565461622.942 total time=   3.9s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-2616254895.972 total time=   4.5s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-2369850715.461 total time=   4.5s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-2363377512.491 total time=   4.6s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-2569079474.212 total time=   4.6s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=200, subsample=1.0;, score=-2495792646.917 total time=   4.7s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-2497067430.496 total time=   6.6s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-2405602999.046 total time=   6.6s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-2266952812.084 total time=   6.5s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-2481910109.640 total time=   6.6s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=0.6;, score=-2394554196.871 total time=   6.5s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-2471251774.871 total time=   8.3s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-2400285407.602 total time=   8.4s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-2236141548.138 total time=   8.2s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-2498944171.184 total time=   8.0s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=0.8;, score=-2415536212.016 total time=   7.7s
# [CV 1/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-2462559193.994 total time=   9.1s
# [CV 2/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-2277907630.308 total time=   9.0s
# [CV 3/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-2237584821.588 total time=   8.9s
# [CV 4/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-2455133726.258 total time=   8.1s
# [CV 5/5] END learning_rate=0.1, max_depth=4, min_samples_leaf=10, n_estimators=400, subsample=1.0;, score=-2389881302.799 total time=   7.7s
# Saved results to gridsearch_results.pkl
# Best parameters:
# {'learning_rate': 0.1, 'max_depth': 4, 'min_samples_leaf': 10, 'n_estimators': 400, 'subsample': 1.0}

# %% [markdown]
# ### Your grade on this assignment will be partially determined by the mean squared error on a separate holdout set. You can approximate this using the test set.

# %%
# Evaluate on test set 
y_pred = best_model.predict(X_test[indep_vars])
mse_best = mse(y_test, y_pred)

print("Test MSE:", mse_best)
# Out:
# Test MSE: 2335373256.259888
